# %%
# for lsf in bin_sfs:
#     bin_l, bin_sf, w = lsf
#     var = bin_sf[-10]/2.
#     acf = (2. * var - bin_sf)/2.
#     print(np.nansum(acf))
#     plt.plot(bin_l, acf/var, zorder=0)
# plt.axhline(1./np.exp(1.), linestyle=(0,(5,5)), color='black', linewidth=1.)
