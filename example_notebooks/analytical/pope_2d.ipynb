# %%
from Kea.utils import plotting
import numpy as np
import matplotlib as mpl
plotting.modify_rc()
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable

import scipy

c = plotting.COLOR_CYCLE_6

from sympy import *
from sympy.core import S

# %%
k = symbols('omega', positive=True, real=True)
l = symbols('s', positive=True, real=True)

nu = symbols('nu', positive=True, real=True)

a = symbols('alpha', positive=True, real=True)

a = sqrt(pi) * gamma(nu + S(1)/S(2))/gamma(nu)
display(a)

E = (S(2)/pi) * (a**2 / (a**2 + k**2))**((S(1) + S(2)*nu) / S(2))

display(E.simplify())

R = integrate(E * sin(k*l)/(k*l), (k, 0, oo))

display(R.simplify())

SF = S(2) * limit(R, l, 0) - S(2) * R
#limit(R, l, 0) = 1

display(SF.simplify())

# Gives the same thing
#SF2 = 2 * integrate((1-cos(k*l))*E, (k, 0, oo))

b = symbols('b', positive=True, real=True)

eq_E = (1/b) * S(1)/S(2) * l**2 * diff(SF, l)

display(eq_E.simplify())
# Out:
# sqrt(pi)*gamma(nu + 1/2)/gamma(nu)
# 2*pi**(nu - 1/2)*(nu*gamma(nu + 1/2))**(2*nu + 1)*(pi*nu**2*gamma(nu + 1/2)**2 + omega**2*gamma(nu + 1)**2)**(-nu - 1/2)
# meijerg(((1,), ()), ((nu + 1/2, 1/2), (0,)), pi*s**2*gamma(nu + 1/2)**2/(4*gamma(nu)**2))/(sqrt(pi)*s*gamma(nu + 1/2))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/sympy/core/assumptions.py:499, in make_property.<locals>.getit(self)
#     498 try:
# --> 499     return self._assumptions[fact]
#     500 except KeyError:
#
# KeyError: 'zero'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/sympy/core/assumptions.py:499, in make_property.<locals>.getit(self)
#     498 try:
# --> 499     return self._assumptions[fact]
#     500 except KeyError:
#
# KeyError: 'zero'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/sympy/core/assumptions.py:499, in make_property.<locals>.getit(self)
#     498 try:
# --> 499     return self._assumptions[fact]
#     500 except KeyError:
#
# KeyError: 'zero'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/sympy/core/assumptions.py:499, in make_property.<locals>.getit(self)
#     498 try:
# --> 499     return self._assumptions[fact]
#     500 except KeyError:
#
# KeyError: 'zero'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/sympy/core/assumptions.py:499, in make_property.<locals>.getit(self)
#     498 try:
# --> 499     return self._assumptions[fact]
#     500 except KeyError:
#
# KeyError: 'integer'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/sympy/utilities/misc.py:560, in as_int(n, strict)
#     559 try:
# --> 560     result = int(n)
#     561 except TypeError:
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/expr.py:320, in Expr.__int__(self)
#     319 if not self.is_number:
# --> 320     raise TypeError("Cannot convert symbols to int")
#     321 r = self.round(2)
#
# TypeError: Cannot convert symbols to int
#
# During handling of the above exception, another exception occurred:
#
# RecursionError                            Traceback (most recent call last)
# Input In [3], in <cell line: 19>()
#      15 R = integrate(E * sin(k*l)/(k*l), (k, 0, oo))
#      17 display(R.simplify())
# ---> 19 SF = S(2) * limit(R, l, 0) - S(2) * R
#      20 #limit(R, l, 0) = 1
#      22 display(SF.simplify())
#
# File ~/.local/lib/python3.10/site-packages/sympy/series/limits.py:64, in limit(e, z, z0, dir)
#      13 def limit(e, z, z0, dir="+"):
#      14     """Computes the limit of ``e(z)`` at the point ``z0``.
#      15
#      16     Parameters
#    (...)
#      61      limit_seq : returns the limit of a sequence.
#      62     """
# ---> 64     return Limit(e, z, z0, dir).doit(deep=False)
#
# File ~/.local/lib/python3.10/site-packages/sympy/series/limits.py:330, in Limit.doit(self, **hints)
#     328     newe = e.subs(z, z + z0)
#     329 try:
# --> 330     coeff, ex = newe.leadterm(z, cdir=cdir)
#     331 except (ValueError, NotImplementedError, PoleError):
#     332     # The NotImplementedError catching is for custom functions
#     333     from sympy.simplify.powsimp import powsimp
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/expr.py:3538, in Expr.leadterm(self, x, logx, cdir)
#    3536 from .symbol import Dummy
#    3537 from sympy.functions.elementary.exponential import log
# -> 3538 l = self.as_leading_term(x, logx=logx, cdir=cdir)
#    3539 d = Dummy('logx')
#    3540 if l.has(log(x)):
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/expr.py:3501, in Expr.as_leading_term(self, logx, cdir, *symbols)
#    3499 if x not in self.free_symbols:
#    3500     return self
# -> 3501 obj = self._eval_as_leading_term(x, logx=logx, cdir=cdir)
#    3502 if obj is not None:
#    3503     from sympy.simplify.powsimp import powsimp
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/mul.py:2035, in Mul._eval_as_leading_term(self, x, logx, cdir)
#    2034 def _eval_as_leading_term(self, x, logx=None, cdir=0):
# -> 2035     return self.func(*[t.as_leading_term(x, logx=logx, cdir=cdir) for t in self.args])
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/mul.py:2035, in <listcomp>(.0)
#    2034 def _eval_as_leading_term(self, x, logx=None, cdir=0):
# -> 2035     return self.func(*[t.as_leading_term(x, logx=logx, cdir=cdir) for t in self.args])
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/expr.py:3501, in Expr.as_leading_term(self, logx, cdir, *symbols)
#    3499 if x not in self.free_symbols:
#    3500     return self
# -> 3501 obj = self._eval_as_leading_term(x, logx=logx, cdir=cdir)
#    3502 if obj is not None:
#    3503     from sympy.simplify.powsimp import powsimp
#
# File ~/.local/lib/python3.10/site-packages/sympy/functions/special/hyper.py:695, in meijerg._eval_as_leading_term(self, x, logx, cdir)
#     693 def _eval_as_leading_term(self, x, logx=None, cdir=0):
#     694     from sympy.simplify.hyperexpand import hyperexpand
# --> 695     return hyperexpand(self).as_leading_term(x, logx=logx, cdir=cdir)
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/expr.py:3501, in Expr.as_leading_term(self, logx, cdir, *symbols)
#    3499 if x not in self.free_symbols:
#    3500     return self
# -> 3501 obj = self._eval_as_leading_term(x, logx=logx, cdir=cdir)
#    3502 if obj is not None:
#    3503     from sympy.simplify.powsimp import powsimp
#
# File ~/.local/lib/python3.10/site-packages/sympy/functions/special/hyper.py:695, in meijerg._eval_as_leading_term(self, x, logx, cdir)
#     693 def _eval_as_leading_term(self, x, logx=None, cdir=0):
#     694     from sympy.simplify.hyperexpand import hyperexpand
# --> 695     return hyperexpand(self).as_leading_term(x, logx=logx, cdir=cdir)
#
#     [... skipping similar frames: meijerg._eval_as_leading_term at line 695 (722 times), Expr.as_leading_term at line 3501 (722 times), __cacheit.<locals>.func_wrapper.<locals>.wrapper at line 72 (722 times)]
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/expr.py:3501, in Expr.as_leading_term(self, logx, cdir, *symbols)
#    3499 if x not in self.free_symbols:
#    3500     return self
# -> 3501 obj = self._eval_as_leading_term(x, logx=logx, cdir=cdir)
#    3502 if obj is not None:
#    3503     from sympy.simplify.powsimp import powsimp
#
# File ~/.local/lib/python3.10/site-packages/sympy/functions/special/hyper.py:695, in meijerg._eval_as_leading_term(self, x, logx, cdir)
#     693 def _eval_as_leading_term(self, x, logx=None, cdir=0):
#     694     from sympy.simplify.hyperexpand import hyperexpand
# --> 695     return hyperexpand(self).as_leading_term(x, logx=logx, cdir=cdir)
#
# File ~/.local/lib/python3.10/site-packages/sympy/simplify/hyperexpand.py:2494, in hyperexpand(f, allow_hyper, rewrite, place)
#    2492     if not r.has(nan, zoo, oo, -oo):
#    2493         return r
# -> 2494 return f.replace(hyper, do_replace).replace(meijerg, do_meijer)
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/basic.py:1666, in Basic.replace(self, query, value, map, simultaneous, exact)
#    1663             expr = v
#    1664     return expr
# -> 1666 rv = walk(self, rec_replace)
#    1667 return (rv, mapping) if map else rv
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/basic.py:1651, in Basic.replace.<locals>.walk(rv, F)
#    1649                     if rv == e and e != newargs[i]:
#    1650                         return rv
# -> 1651     rv = F(rv)
#    1652 return rv
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/basic.py:1659, in Basic.replace.<locals>.rec_replace(expr)
#    1657 result = _query(expr)
#    1658 if result or result == {}:
# -> 1659     v = _value(expr, result)
#    1660     if v is not None and v != expr:
#    1661         if map:
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/basic.py:1588, in Basic.replace.<locals>.<lambda>(expr, result)
#    1586     _value = lambda expr, result: value(*expr.args)
#    1587 elif callable(value):
# -> 1588     _value = lambda expr, result: value(*expr.args)
#    1589 else:
#    1590     raise TypeError(
#    1591         "given a type, replace() expects another "
#    1592         "type or a callable")
#
# File ~/.local/lib/python3.10/site-packages/sympy/simplify/hyperexpand.py:2490, in hyperexpand.<locals>.do_meijer(ap, bq, z)
#    2489 def do_meijer(ap, bq, z):
# -> 2490     r = _meijergexpand(G_Function(ap[0], ap[1], bq[0], bq[1]), z,
#    2491                allow_hyper, rewrite=rewrite, place=place)
#    2492     if not r.has(nan, zoo, oo, -oo):
#    2493         return r
#
# File ~/.local/lib/python3.10/site-packages/sympy/simplify/hyperexpand.py:2368, in _meijergexpand(func, z0, allow_hyper, rewrite, place)
#    2365     return res, cond
#    2367 t = Dummy('t')
# -> 2368 slater1, cond1 = do_slater(func.an, func.bm, func.ap, func.bq, z, z0)
#    2370 def tr(l):
#    2371     return [1 - x for x in l]
#
# File ~/.local/lib/python3.10/site-packages/sympy/simplify/hyperexpand.py:2301, in _meijergexpand.<locals>.do_slater(an, bm, ap, bq, z, zfinal)
#    2298     # NOTE even though k "is" +-1, this has to be t/k instead of
#    2299     #      t*k ... we are using polar numbers for consistency!
#    2300     premult = (t/k)**bh
# -> 2301     hyp = _hyperexpand(Hyper_Function(nap, nbq), harg, ops,
#    2302                        t, premult, bh, rewrite=None)
#    2303     res += fac * hyp
#    2304 else:
#
# File ~/.local/lib/python3.10/site-packages/sympy/simplify/hyperexpand.py:2058, in _hyperexpand(func, z, ops0, z0, premult, prem, rewrite)
#    2055 # Now carry out the plan.
#    2056 r = carryout_plan(formula, ops) + p
# -> 2058 return powdenest(r, polar=True).replace(hyper, hyperexpand_special)
#
# File ~/.local/lib/python3.10/site-packages/sympy/simplify/powsimp.py:603, in powdenest(eq, force, polar)
#     600     return powdenest(eq, force=False, polar=polar).xreplace(reps)
#     602 if polar:
# --> 603     eq, rep = polarify(eq)
#     604     return unpolarify(powdenest(unpolarify(eq, exponents_only=True)), rep)
#     606 new = powsimp(eq)
#
# File ~/.local/lib/python3.10/site-packages/sympy/functions/elementary/complexes.py:1390, in polarify(eq, subs, lift)
#    1388     return eq
#    1389 reps = {s: Dummy(s.name, polar=True) for s in eq.free_symbols}
# -> 1390 eq = eq.subs(reps)
#    1391 return eq, {r: s for s, r in reps.items()}
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/basic.py:1040, in Basic.subs(self, *args, **kwargs)
#    1038 rv = self
#    1039 for old, new in sequence:
# -> 1040     rv = rv._subs(old, new, **kwargs)
#    1041     if not isinstance(rv, Basic):
#    1042         break
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/basic.py:1154, in Basic._subs(self, old, new, **hints)
#    1152 rv = self._eval_subs(old, new)
#    1153 if rv is None:
# -> 1154     rv = fallback(self, old, new)
#    1155 return rv
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/basic.py:1131, in Basic._subs.<locals>.fallback(self, old, new)
#    1129         args[i] = arg
#    1130 if hit:
# -> 1131     rv = self.func(*args)
#    1132     hack2 = hints.get('hack2', False)
#    1133     if hack2 and self.is_Mul and not rv.is_Mul:  # 2-arg hack
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/operations.py:98, in AssocOp.__new__(cls, evaluate, _sympify, *args)
#      95 if len(args) == 1:
#      96     return args[0]
# ---> 98 c_part, nc_part, order_symbols = cls.flatten(args)
#      99 is_commutative = not nc_part
#     100 obj = cls._from_args(c_part + nc_part, is_commutative)
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/mul.py:285, in Mul.flatten(cls, seq)
#     283     seq = [a, b]
#     284 assert a is not S.One
# --> 285 if not a.is_zero and a.is_Rational:
#     286     r, b = b.as_coeff_Mul()
#     287     if b.is_Add:
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/assumptions.py:503, in make_property.<locals>.getit(self)
#     501 if self._assumptions is self.default_assumptions:
#     502     self._assumptions = self.default_assumptions.copy()
# --> 503 return _ask(fact, self)
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/assumptions.py:559, in _ask(fact, obj)
#     557 handler_i = handler_map.get(fact_i)
#     558 if handler_i is not None:
# --> 559     fact_i_value = handler_i(obj)
#     561 # If we get a new value for fact_i then we should update our knowledge
#     562 # of fact_i as well as any related facts that can be inferred using the
#     563 # inference rules connecting the fact_i and any other fact values that
#     564 # are already known.
#     565 if fact_i_value is not None:
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/power.py:620, in Pow._eval_is_zero(self)
#     619 def _eval_is_zero(self):
# --> 620     if self.base.is_zero:
#     621         if self.exp.is_extended_positive:
#     622             return True
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/assumptions.py:503, in make_property.<locals>.getit(self)
#     501 if self._assumptions is self.default_assumptions:
#     502     self._assumptions = self.default_assumptions.copy()
# --> 503 return _ask(fact, self)
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/assumptions.py:559, in _ask(fact, obj)
#     557 handler_i = handler_map.get(fact_i)
#     558 if handler_i is not None:
# --> 559     fact_i_value = handler_i(obj)
#     561 # If we get a new value for fact_i then we should update our knowledge
#     562 # of fact_i as well as any related facts that can be inferred using the
#     563 # inference rules connecting the fact_i and any other fact values that
#     564 # are already known.
#     565 if fact_i_value is not None:
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/mul.py:1347, in Mul._eval_is_zero(self)
#    1344 def _eval_is_zero(self):
#    1345     # True iff any arg is zero and no arg is infinite but need to handle
#    1346     # three valued logic carefully.
# -> 1347     seen_zero, seen_infinite = self._eval_is_zero_infinite_helper()
#    1349     if seen_zero is False:
#    1350         return False
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/mul.py:1324, in Mul._eval_is_zero_infinite_helper(self)
#    1321 seen_zero = seen_infinite = False
#    1323 for a in self.args:
# -> 1324     if a.is_zero:
#    1325         if seen_infinite is not False:
#    1326             return None, None
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/assumptions.py:503, in make_property.<locals>.getit(self)
#     501 if self._assumptions is self.default_assumptions:
#     502     self._assumptions = self.default_assumptions.copy()
# --> 503 return _ask(fact, self)
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/assumptions.py:559, in _ask(fact, obj)
#     557 handler_i = handler_map.get(fact_i)
#     558 if handler_i is not None:
# --> 559     fact_i_value = handler_i(obj)
#     561 # If we get a new value for fact_i then we should update our knowledge
#     562 # of fact_i as well as any related facts that can be inferred using the
#     563 # inference rules connecting the fact_i and any other fact values that
#     564 # are already known.
#     565 if fact_i_value is not None:
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/power.py:1445, in Pow._eval_is_algebraic(self)
#    1441     except ValueError:
#    1442         # when the operation is not allowed
#    1443         return False
# -> 1445 if self.base.is_zero or _is_one(self.base):
#    1446     return True
#    1447 elif self.base is S.Exp1:
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/power.py:1440, in Pow._eval_is_algebraic.<locals>._is_one(expr)
#    1438 def _is_one(expr):
#    1439     try:
# -> 1440         return (expr - 1).is_zero
#    1441     except ValueError:
#    1442         # when the operation is not allowed
#    1443         return False
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/assumptions.py:503, in make_property.<locals>.getit(self)
#     501 if self._assumptions is self.default_assumptions:
#     502     self._assumptions = self.default_assumptions.copy()
# --> 503 return _ask(fact, self)
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/assumptions.py:559, in _ask(fact, obj)
#     557 handler_i = handler_map.get(fact_i)
#     558 if handler_i is not None:
# --> 559     fact_i_value = handler_i(obj)
#     561 # If we get a new value for fact_i then we should update our knowledge
#     562 # of fact_i as well as any related facts that can be inferred using the
#     563 # inference rules connecting the fact_i and any other fact values that
#     564 # are already known.
#     565 if fact_i_value is not None:
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/add.py:646, in Add.<lambda>(self)
#     642 _eval_is_finite = lambda self: _fuzzy_group(
#     643     (a.is_finite for a in self.args), quick_exit=True)
#     644 _eval_is_hermitian = lambda self: _fuzzy_group(
#     645     (a.is_hermitian for a in self.args), quick_exit=True)
# --> 646 _eval_is_integer = lambda self: _fuzzy_group(
#     647     (a.is_integer for a in self.args), quick_exit=True)
#     648 _eval_is_rational = lambda self: _fuzzy_group(
#     649     (a.is_rational for a in self.args), quick_exit=True)
#     650 _eval_is_algebraic = lambda self: _fuzzy_group(
#     651     (a.is_algebraic for a in self.args), quick_exit=True)
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/logic.py:81, in _fuzzy_group(args, quick_exit)
#      44 """Return True if all args are True, None if there is any None else False
#      45 unless ``quick_exit`` is True (then return None as soon as a second False
#      46 is seen.
#    (...)
#      78
#      79 """
#      80 saw_other = False
# ---> 81 for a in args:
#      82     if a is True:
#      83         continue
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/add.py:647, in <genexpr>(.0)
#     642 _eval_is_finite = lambda self: _fuzzy_group(
#     643     (a.is_finite for a in self.args), quick_exit=True)
#     644 _eval_is_hermitian = lambda self: _fuzzy_group(
#     645     (a.is_hermitian for a in self.args), quick_exit=True)
#     646 _eval_is_integer = lambda self: _fuzzy_group(
# --> 647     (a.is_integer for a in self.args), quick_exit=True)
#     648 _eval_is_rational = lambda self: _fuzzy_group(
#     649     (a.is_rational for a in self.args), quick_exit=True)
#     650 _eval_is_algebraic = lambda self: _fuzzy_group(
#     651     (a.is_algebraic for a in self.args), quick_exit=True)
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/assumptions.py:503, in make_property.<locals>.getit(self)
#     501 if self._assumptions is self.default_assumptions:
#     502     self._assumptions = self.default_assumptions.copy()
# --> 503 return _ask(fact, self)
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/assumptions.py:559, in _ask(fact, obj)
#     557 handler_i = handler_map.get(fact_i)
#     558 if handler_i is not None:
# --> 559     fact_i_value = handler_i(obj)
#     561 # If we get a new value for fact_i then we should update our knowledge
#     562 # of fact_i as well as any related facts that can be inferred using the
#     563 # inference rules connecting the fact_i and any other fact values that
#     564 # are already known.
#     565 if fact_i_value is not None:
#
# File ~/.local/lib/python3.10/site-packages/sympy/functions/special/gamma_functions.py:180, in gamma._eval_is_real(self)
#     178 if x.is_nonpositive and x.is_integer:
#     179     return False
# --> 180 if intlike(x) and x <= 0:
#     181     return False
#     182 if x.is_positive or x.is_noninteger:
#
# File ~/.local/lib/python3.10/site-packages/sympy/functions/special/gamma_functions.py:25, in intlike(n)
#      23 def intlike(n):
#      24     try:
# ---> 25         as_int(n, strict=False)
#      26         return True
#      27     except ValueError:
#
# File ~/.local/lib/python3.10/site-packages/sympy/utilities/misc.py:562, in as_int(n, strict)
#     560     result = int(n)
#     561 except TypeError:
# --> 562     raise ValueError('%s is not an integer' % (n,))
#     563 if n != result:
#     564     raise ValueError('%s is not an integer' % (n,))
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/_print_helpers.py:29, in Printable.__str__(self)
#      27 def __str__(self):
#      28     from sympy.printing.str import sstr
# ---> 29     return sstr(self, order=None)
#
# File ~/.local/lib/python3.10/site-packages/sympy/printing/printer.py:372, in _PrintFunction.__call__(self, *args, **kwargs)
#     371 def __call__(self, *args, **kwargs):
# --> 372     return self.__wrapped__(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/sympy/printing/str.py:998, in sstr(expr, **settings)
#     982 """Returns the expression as a string.
#     983
#     984 For large expressions where speed is a concern, use the setting
#    (...)
#     994 'Eq(a + b, 0)'
#     995 """
#     997 p = StrPrinter(settings)
# --> 998 s = p.doprint(expr)
#    1000 return s
#
# File ~/.local/lib/python3.10/site-packages/sympy/printing/printer.py:292, in Printer.doprint(self, expr)
#     290 def doprint(self, expr):
#     291     """Returns printer's representation for expr (as a string)"""
# --> 292     return self._str(self._print(expr))
#
# File ~/.local/lib/python3.10/site-packages/sympy/printing/printer.py:331, in Printer._print(self, expr, **kwargs)
#     329     printmethod = getattr(self, printmethodname, None)
#     330     if printmethod is not None:
# --> 331         return printmethod(expr, **kwargs)
#     332 # Unknown object, fall back to the emptyPrinter.
#     333 return self.emptyPrinter(expr)
#
# File ~/.local/lib/python3.10/site-packages/sympy/printing/str.py:52, in StrPrinter._print_Add(self, expr, order)
#      51 def _print_Add(self, expr, order=None):
# ---> 52     terms = self._as_ordered_terms(expr, order=order)
#      54     prec = precedence(expr)
#      55     l = []
#
# File ~/.local/lib/python3.10/site-packages/sympy/printing/printer.py:349, in Printer._as_ordered_terms(self, expr, order)
#     347     return list(expr.args)
#     348 else:
# --> 349     return expr.as_ordered_terms(order=order)
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/expr.py:1146, in Expr.as_ordered_terms(self, order, data)
#    1143             return add_args
#    1145 key, reverse = self._parse_order(order)
# -> 1146 terms, gens = self.as_terms()
#    1148 if not any(term.is_Order for term, _ in terms):
#    1149     ordered = sorted(terms, key=key, reverse=reverse)
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/expr.py:1176, in Expr.as_terms(self)
#    1173 for term in Add.make_args(self):
#    1174     coeff, _term = term.as_coeff_Mul()
# -> 1176     coeff = complex(coeff)
#    1177     cpart, ncpart = {}, []
#    1179     if _term is not S.One:
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/expr.py:355, in Expr.__complex__(self)
#     353 def __complex__(self):
#     354     result = self.evalf()
# --> 355     re, im = result.as_real_imag()
#     356     return complex(float(re), float(im))
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/expr.py:1934, in Expr.as_real_imag(self, deep, **hints)
#    1932 else:
#    1933     from sympy.functions.elementary.complexes import im, re
# -> 1934     return (re(self), im(self))
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/numbers.py:1375, in Float.__eq__(self, other)
#    1373 from sympy.logic.boolalg import Boolean
#    1374 try:
# -> 1375     other = _sympify(other)
#    1376 except SympifyError:
#    1377     return NotImplemented
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/sympify.py:528, in _sympify(a)
#     502 def _sympify(a):
#     503     """
#     504     Short version of :func:`~.sympify` for internal usage for ``__add__`` and
#     505     ``__eq__`` methods where it is ok to allow some things (like Python
#    (...)
#     526
#     527     """
# --> 528     return sympify(a, strict=True)
#
# File ~/.local/lib/python3.10/site-packages/sympy/core/sympify.py:361, in sympify(a, locals, convert_xor, strict, rational, evaluate)
#     103 """
#     104 Converts an arbitrary expression to a type that can be used inside SymPy.
#     105
#    (...)
#     351
#     352 """
#     353 # XXX: If a is a Basic subclass rather than instance (e.g. sin rather than
#     354 # sin(x)) then a.__sympy__ will be the property. Only on the instance will
#     355 # a.__sympy__ give the *value* of the property (True). Since sympify(sin)
#    (...)
#     359 #
#     360 # https://github.com/sympy/sympy/issues/20124
# --> 361 is_sympy = getattr(a, '__sympy__', None)
#     362 if is_sympy is True:
#     363     return a
#
# RecursionError: maximum recursion depth exceeded

# %%
fig, ax = plt.subplots(1, 1, figsize=(3.5, 3.5), dpi=256)

_k = np.exp(np.linspace(np.log(0.1), np.log(512), 512))
_nu = 0.7

for __k in _k:
    val = E.subs({k: __k, nu: _nu}).evalf()
    ax.scatter(__k, val, marker='o', s=5., color='black', zorder=2, linewidth=0.2, edgecolor='black')

    val1 = eq_E.subs({l: 1./__k, nu: _nu, b: 1.}).evalf()
    ax.scatter(__k, val1, marker='o', s=5., color='red', zorder=2, linewidth=0.2, edgecolor='black')

ax.loglog()

ax.set_title(r'$p \approx$ %s' % (1. + 2.*_nu))

ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.tick_params(axis='y', direction='in')
ax.tick_params(axis='y', direction='in', which='minor')
ax.tick_params(axis='x', direction='in')
ax.tick_params(axis='x', direction='in', which='minor')
ax.grid(linestyle=':', alpha=0.3, linewidth=0.5, color='gray')

ax.set_ylabel(r'1D Omni-spectrum, $\mathcal{E}_1(\omega)$')
ax.set_xlabel(r'Angular frequency, $\omega$')

ax.set_ylim((1e-6, 1e1))
# Out:
# (1e-06, 10.0)

# %%
NUM = 10
cols = plt.get_cmap('Greys')(np.linspace(0.25, 1., NUM))
cols1 = plt.cm.Reds(np.linspace(0.25, 1., NUM))
cols2 = plt.cm.Blues(np.linspace(0.25, 1., NUM))
cols3 = plt.cm.Greens(np.linspace(0.25, 1., NUM))
upper_cmap = mpl.colors.LinearSegmentedColormap.from_list('Upper', cols2)

fig, ax = plt.subplots(1, 2, figsize=(7., 3.5), dpi=256)

ratio = eq_E.subs({l: 1/k, b: 1}) / E
display(ratio.simplify())

_k = np.exp(np.linspace(np.log(1), np.log(512), 512))
_nu = np.linspace(1./6., 2., NUM)

R1 = []
for i, __nu in enumerate(_nu):
    E1 = []
    E2 = []
    ER = []
    for __k in _k:
        val1 = E.subs({k: __k, nu: __nu}).evalf()
        E1.append(val1)
        val2 = eq_E.subs({l: 1./__k, nu: __nu, b: 1.}).evalf()
        E2.append(val2)
        val3 = ratio.subs({k: __k, nu: __nu}).evalf()
        ER.append(val3)

    E1 = np.array(E1)
    E2 = np.array(E2)
    R1.append(np.mean(np.array(ER)))

    ax[0].plot(_k, E2/E1, color=cols2[i], linewidth=1.)
    ax[1].scatter(__nu, np.mean(E2/E1), marker='X', s=5., color=cols2[i], zorder=2, linewidth=0.2, edgecolor='black')

ax[1].plot(_nu, R1, linewidth=1., color='black', zorder=1, linestyle=(0,(5,5)))

ax[1].axvspan(0, 1., alpha=0.2, color='gray', zorder=0)

ax[0].loglog()
ax[1].set_yscale('log')

for axx in ax:
    axx.yaxis.set_ticks_position('both')
    axx.xaxis.set_ticks_position('both')
    axx.tick_params(axis='y', direction='in')
    axx.tick_params(axis='y', direction='in', which='minor')
    axx.tick_params(axis='x', direction='in')
    axx.tick_params(axis='x', direction='in', which='minor')
    axx.grid(linestyle=':', alpha=0.3, linewidth=0.5, color='gray')

ax[0].set_ylabel(r'Bias, $\tilde{\mathcal{E}}_1^S(\omega)/\mathcal{E}_1(\omega)$')
ax[0].set_xlabel(r'Angular frequency, $\omega$')

ax[1].set_ylabel(r'Avg. Bias, $\langle \tilde{\mathcal{E}}_1^S(\omega)/\mathcal{E}_1(\omega) \rangle$')
ax[1].set_xlabel(r'Hurst parameter, $H$')
#ax.set_ylim((1e-6, 1e1))
# Out:
# pi**(1/2 - nu/2)*(1/(2*omega))**(nu + 2)*(1/(nu*gamma(nu + 1/2)))**(nu + 1)*(pi*nu**2*gamma(nu + 1/2)**2 + omega**2*gamma(nu + 1)**2)**(nu + 1/2)*(-2*omega*besseli(-nu, sqrt(pi)*gamma(nu + 1/2)/(omega*gamma(nu)))*gamma(nu + 1) + 2*omega*besseli(nu, sqrt(pi)*gamma(nu + 1/2)/(omega*gamma(nu)))*gamma(nu + 1) - sqrt(pi)*besseli(1 - nu, sqrt(pi)*gamma(nu + 1/2)/(omega*gamma(nu)))*gamma(nu + 1/2) - sqrt(pi)*besseli(-nu - 1, sqrt(pi)*gamma(nu + 1/2)/(omega*gamma(nu)))*gamma(nu + 1/2) + sqrt(pi)*besseli(nu - 1, sqrt(pi)*gamma(nu + 1/2)/(omega*gamma(nu)))*gamma(nu + 1/2) + sqrt(pi)*besseli(nu + 1, sqrt(pi)*gamma(nu + 1/2)/(omega*gamma(nu)))*gamma(nu + 1/2))*gamma(1 - nu)/(gamma(nu)*gamma(nu + 1)**nu)

# %%
fig, ax = plt.subplots(1, 1, figsize=(3.5, 3.5), dpi=256)

_l = np.exp(np.linspace(np.log(1), np.log(10), 512))
_nu = 1.5

for __l in _l:
    val = R.subs({l: __l, nu: _nu}).evalf()
    ax.scatter(__l, val, marker='o', s=5., color='red', zorder=2, linewidth=0.2, edgecolor='black')

ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.tick_params(axis='y', direction='in')
ax.tick_params(axis='y', direction='in', which='minor')
ax.tick_params(axis='x', direction='in')
ax.tick_params(axis='x', direction='in', which='minor')
ax.grid(linestyle=':', alpha=0.3, linewidth=0.5, color='gray')

ax.set_ylabel(r'$R(\lambda)$')
ax.set_xlabel(r'$\lambda$')
# Out:
# Text(0.5, 0, '$\\lambda$')

# %%
fig, ax = plt.subplots(1, 1, figsize=(3.5, 3.5), dpi=256)

_l = np.exp(np.linspace(np.log(0.01), np.log(10), 512))
_nu = 1.5

for __l in _l:
    val = SF.subs({l: __l, nu: _nu}).evalf()
    ax.scatter(__l, val, marker='o', s=5., color='red', zorder=2, linewidth=0.2, edgecolor='black')

ax.loglog()

ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.tick_params(axis='y', direction='in')
ax.tick_params(axis='y', direction='in', which='minor')
ax.tick_params(axis='x', direction='in')
ax.tick_params(axis='x', direction='in', which='minor')
ax.grid(linestyle=':', alpha=0.3, linewidth=0.5, color='gray')

ax.set_ylabel(r'$S_2(\lambda)$')
ax.set_xlabel(r'$\lambda$')
# Out:
# Text(0.5, 0, '$\\lambda$')
